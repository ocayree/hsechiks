# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import time
import requests

# %%
options = webdriver.ChromeOptions()
driver = webdriver.Chrome()
actions = ActionChains(driver)
prices = []
names = []

url = "https://www.avito.ru/moskva_i_mo/ptitsy?cd=1&q=куры+несушки"
driver.get(url)
actions.send_keys(Keys.END).perform()
time.sleep(5)
actions.send_keys(Keys.END).perform()
time.sleep(5)
actions.send_keys(Keys.END).perform()
time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[36], line 14
#      12 url = "https://www.avito.ru/moskva_i_mo/ptitsy?cd=1&q=куры+несушки"
#      13 driver.get(url)
# ---> 14 actions.send_keys(Keys.END).perform()
#      15 time.sleep(5)
#      16 actions.send_keys(Keys.END).perform()
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\common\action_chains.py:94, in ActionChains.perform(self)
#      92 def perform(self) -> None:
#      93     """Performs all stored actions."""
# ---> 94     self.w3c_actions.perform()
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\common\actions\action_builder.py:96, in ActionBuilder.perform(self)
#      94         enc["actions"].append(encoded)
#      95         device.actions = []
# ---> 96 self.driver.execute(Command.W3C_ACTIONS, enc)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=134.0.6998.117)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF753BDFE65+26629]
# 	(No symbol) [0x00007FF753B46030]
# 	(No symbol) [0x00007FF7539D931A]
# 	(No symbol) [0x00007FF7539B1753]
# 	(No symbol) [0x00007FF753A5F6BE]
# 	(No symbol) [0x00007FF753A7FA55]
# 	(No symbol) [0x00007FF753A57883]
# 	(No symbol) [0x00007FF753A20550]
# 	(No symbol) [0x00007FF753A21803]
# 	GetHandleVerifier [0x00007FF753F372DD+3529853]
# 	GetHandleVerifier [0x00007FF753F4DA42+3621858]
# 	GetHandleVerifier [0x00007FF753F424F3+3575443]
# 	GetHandleVerifier [0x00007FF753CAB79A+860474]
# 	(No symbol) [0x00007FF753B508AF]
# 	(No symbol) [0x00007FF753B4CBE4]
# 	(No symbol) [0x00007FF753B4CD86]
# 	(No symbol) [0x00007FF753B3C2E9]
# 	BaseThreadInitThunk [0x00007FF94E05E8D7+23]
# 	RtlUserThreadStart [0x00007FF94ECDBF6C+44]

# %%
names = driver.find_elements(By.CLASS_NAME, "iva-item-titleStep-zichc")
names = [name.text for name in names] 
names
# Out:
# ['Куры несушки',
#  'Куры',
#  'Куры несушки',
#  'Куры несушки с доставкой',
#  'Куры несушки, самые лучшие у нас',
#  'Куры несушки с бесплатной доставкой',
#  'Куры несушки продам',
#  'Куры Молодки несушки. 4-5мес',
#  'Куры несушки',
#  'Куры несушки',
#  'Куры несушки 3 - 4 месяца',
#  'Куры несушки',
#  'Куры молодки несушки',
#  'Куры несушки хайсекс',
#  'Куры несушки',
#  'Куры несушки',
#  'Куры несушки',
#  'Куры несушки доминанты супер ник',
#  'Ищете кур несушек, которые несут 5 яиц в день',
#  'Куры молодки несушки',
#  'Куры несушки продам',
#  'Куры доминант с цветным яйцом',
#  'Куры несушки молодки',
#  'Куры несушки с доставкой',
#  'Куры-несушки молодки',
#  'Куры несушки молодки',
#  'Куры несушки продам',
#  'Куры несушки Хайсекс- белые и рыжие. Доминанты',
#  'Курочки молодки несушки',
#  'Курочки несушки с доставкой до дома',
#  'Курочки несушки с доставкой',
#  'Куры несушки с бесплатной доставкой',
#  'Куры молодки несушки',
#  'Куры несушки',
#  'Куры несушки',
#  'Куры молодки несушки',
#  'Куры несушки с доставкой',
#  'Куры несушки',
#  'Куры несушки молодки',
#  'Куры молодки',
#  'Куры молодки несушки домашние',
#  'Куры несушки',
#  'Курицы несушки',
#  'Куры несушки',
#  'Курицы несушки молодки. Перепёлки.Кролики',
#  'Куры несушки с доставкой до дома',
#  'Продажа домашней птицы',
#  'Куры несушки молодки. Ломан, Хайсекс, Цесарки',
#  'Куры несушки',
#  'Куры несушки молодки с доставкой']

# %%
prices = driver.find_elements(By.CSS_SELECTOR, "meta[itemprop='price']")
prices = [price.get_attribute('content') for price in prices]
prices
# Out:
# ['90',
#  '0',
#  '530',
#  '550',
#  '450',
#  '510',
#  '450',
#  '0',
#  '600',
#  '540',
#  '580',
#  '0',
#  '530',
#  '450',
#  '0',
#  '450',
#  '0',
#  '650',
#  '0',
#  '530',
#  '650',
#  '0',
#  '510',
#  '530',
#  '530',
#  '530',
#  '80',
#  '600',
#  '0',
#  '520',
#  '530',
#  '0',
#  '570',
#  '550',
#  '520',
#  '0',
#  '540',
#  '0',
#  '540',
#  '520',
#  '750',
#  '0',
#  '400',
#  '530',
#  '650',
#  '540',
#  '1',
#  '0',
#  '530',
#  '450']
